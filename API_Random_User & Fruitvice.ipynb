# %% [markdown]
# ### Random User and Fruitvice API examples

# %% [markdown]
# **Objectives:**

# %% [markdown]
# - To load & use RandomUser API, using `RandomUser()` Python library
# - To load & use Fruitvice API, using `requests` Python library

# %% [markdown]
# The advantages of using APIs:
#
# - **Automation** Less human effort is required and workflows can be easily updated to become faster and more productive
# - **Efficiency** It allows to use the capabilities of one of the already developed APIs than to try to independently implement some functionality from scratch.

# %% [markdown]
# The disadvantage of using APIs:

# %% [markdown]
#  - **Security** If the API is poorly integrated, it means it will be vulnerable to attacks, resulting in data breeches or losses having financial or reputation implications.

# %% [markdown]
# ### Application: Random User Generator

# %% [markdown]
# RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This make the tool similar to Lorem Ipsum, but is a placeholder for people instead of text.
# The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more.

# %% [markdown]
# ### Application: Fruitvice API

# %% [markdown]
# The Fruitvice API webservice which provides data for all kinds of fruits. You can use Fruitvice to find all interesting information about fruit and educate yourself.

# %% [markdown]
# ### Example 1: RandomUser API

# %% [markdown]
# Below are Get Methods parameters that we can generate.

# %% [markdown]
# **Get Methods:**

# %% [markdown]
# - get_cell()
# - get_city()
# - get_dob()
# - get_email()
# - get_first_name()
# - get_full_name()
# - get_gender()
# - get_id()
# - get_id_number()
# - get_id_type()
# - get_info()
# - get_last_name()
# - get_login_md5()
# - get_login_salt()
# - get_login_sha1()
# - get_login_sha256()
# - get_nat()
# - get_password()
# - get_phone()
# - get_picture()
# - get_postcode()
# - get_registered()
# - get_state()
# - get_street()
# - get_username()
# - get_zipcode()

# %%
# install randomuser

# !pip install randomuser
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py) ... done
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5066 sha256=b4c6168ccafab11e0b24a0e0bca4d4b14f0c7e460f3df57afb2b8bb930a91d6c
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/21/10/7b/c13bc3e24a3c1000a34554802ad8aa0ff27df56366998a0473
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6

# %%
# load libraries

from randomuser import RandomUser
import pandas as pd

# %%
# create a random user object, r.

r = RandomUser()

# %%
# get list of random 15 users using generate_users() function: 

some_list = r.generate_users(15)
some_list
# Out:
# [<randomuser.RandomUser at 0x7f2495b41f50>,
#  <randomuser.RandomUser at 0x7f2495b41d90>,
#  <randomuser.RandomUser at 0x7f2495b41e50>,
#  <randomuser.RandomUser at 0x7f2495b41dd0>,
#  <randomuser.RandomUser at 0x7f2495b416d0>,
#  <randomuser.RandomUser at 0x7f2495b41b90>,
#  <randomuser.RandomUser at 0x7f2495b41890>,
#  <randomuser.RandomUser at 0x7f2495b41610>,
#  <randomuser.RandomUser at 0x7f2495b41c50>,
#  <randomuser.RandomUser at 0x7f2495b41e90>,
#  <randomuser.RandomUser at 0x7f2495b41690>,
#  <randomuser.RandomUser at 0x7f2495b41650>,
#  <randomuser.RandomUser at 0x7f2495b41bd0>,
#  <randomuser.RandomUser at 0x7f2495b41910>,
#  <randomuser.RandomUser at 0x7f2495b41c10>]

# %%
# Get full name, using get_full_name() function

name = r.get_full_name()

# %%
# need 10 users with full names and their email addresses

for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Anne Heggelund   anne.heggelund@example.com
# Zachary Ennis   zachary.ennis@example.com
# Akshay De Cock   akshay.decock@example.com
# Eirill Oshaug   eirill.oshaug@example.com
# Simon Sørensen   simon.sorensen@example.com
# Megan Harris   megan.harris@example.com
# Onur Toraman   onur.toraman@example.com
# Ryder Slawa   ryder.slawa@example.com
# Pihla Lampo   pihla.lampo@example.com
# Carl Jensen   carl.jensen@example.com
# Aras Sjåvik   aras.sjavik@example.com
# Sebastian Moreno   sebastian.moreno@example.com
# Truls Midtskogen   truls.midtskogen@example.com
# Bella Johnson   bella.johnson@example.com
# Lily Lévesque   lily.levesque@example.com

# %%
# generate photos of random 15 users

for user in some_list:
    print (user.get_picture())
# Out:
# https://randomuser.me/api/portraits/women/15.jpg
# https://randomuser.me/api/portraits/men/18.jpg
# https://randomuser.me/api/portraits/men/62.jpg
# https://randomuser.me/api/portraits/women/18.jpg
# https://randomuser.me/api/portraits/men/47.jpg
# https://randomuser.me/api/portraits/women/58.jpg
# https://randomuser.me/api/portraits/men/39.jpg
# https://randomuser.me/api/portraits/men/1.jpg
# https://randomuser.me/api/portraits/women/47.jpg
# https://randomuser.me/api/portraits/men/18.jpg
# https://randomuser.me/api/portraits/men/18.jpg
# https://randomuser.me/api/portraits/men/46.jpg
# https://randomuser.me/api/portraits/men/33.jpg
# https://randomuser.me/api/portraits/women/2.jpg
# https://randomuser.me/api/portraits/women/47.jpg

# %%
# generate table with desirable parameters

def get_users():
    users=[]
    
    for user in RandomUser.generate_users(15):
        users.append({"Name":user.get_full_name(), "Gender": user.get_gender(), "City": user.get_city(), "State": user.get_state(), "Email": user.get_email(), "DOB": user.get_dob(), "Picture": user.get_picture()})
    
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                    Name  Gender                      City  \
# 0         Harriet Brown  female          Palmerston North
# 1          Nelli Hakola  female                  Kimitoön
# 2     Kristupas Rødland    male                   Granvin
# 3     Bibiana Fernandes  female                    Jequié
# 4              آوا گلشن  female                    سیرجان
# 5          Norah Dupont  female                    Toulon
# 6            Ray Warren    male                 Liverpool
# 7           Karl Walker    male                    Albury
# 8       Ioannis Sattler    male                     Calau
# 9       Benjamin Morris    male                Wellington
# 10  Steve Van der Leeuw    male  Voorst Oude Ijsselstreek
# 11        Maciej Øglænd    male                    Byremo
# 12        Jason Garrett    male                 Cambridge
# 13      Taylor Jennings    male                    Arklow
# 14        Amelia Walker  female                  Beaumont
#
#                    State                          Email  \
# 0             Canterbury      harriet.brown@example.com
# 1                  Åland       nelli.hakola@example.com
# 2   Finnmark - Finnmárku  kristupas.rodland@example.com
# 3         Rio de Janeiro  bibiana.fernandes@example.com
# 4                  تهران           aw.glshn@example.com
# 5         Indre-et-Loire       norah.dupont@example.com
# 6                Suffolk         ray.warren@example.com
# 7               Tasmania        karl.walker@example.com
# 8                Hamburg    ioannis.sattler@example.com
# 9             West Coast    benjamin.morris@example.com
# 10         Noord-Holland  steve.vanderleeuw@example.com
# 11           Description     maciej.oglaend@example.com
# 12        South Carolina      jason.garrett@example.com
# 13               Kildare    taylor.jennings@example.com
# 14                 Yukon      amelia.walker@example.com
#
#                          DOB                                           Picture
# 0   1961-08-17T07:31:57.601Z  https://randomuser.me/api/portraits/women/80.jpg
# 1   1982-04-09T13:53:04.518Z  https://randomuser.me/api/portraits/women/49.jpg
# 2   1984-08-05T11:48:38.848Z    https://randomuser.me/api/portraits/men/57.jpg
# 3   1950-07-06T04:52:20.915Z   https://randomuser.me/api/portraits/women/1.jpg
# 4   1986-04-20T11:44:10.738Z  https://randomuser.me/api/portraits/women/66.jpg
# 5   1997-06-01T00:13:49.848Z  https://randomuser.me/api/portraits/women/10.jpg
# 6   1976-03-24T10:47:42.200Z    https://randomuser.me/api/portraits/men/29.jpg
# 7   1977-09-08T12:41:18.665Z     https://randomuser.me/api/portraits/men/8.jpg
# 8   1968-04-26T22:54:45.162Z    https://randomuser.me/api/portraits/men/27.jpg
# 9   1988-03-08T21:47:28.978Z    https://randomuser.me/api/portraits/men/11.jpg
# 10  1961-02-04T03:30:41.367Z    https://randomuser.me/api/portraits/men/62.jpg
# 11  1962-10-29T23:10:13.062Z    https://randomuser.me/api/portraits/men/84.jpg
# 12  1962-01-31T20:51:04.592Z    https://randomuser.me/api/portraits/men/41.jpg
# 13  1983-11-22T15:43:09.924Z    https://randomuser.me/api/portraits/men/27.jpg
# 14  1972-10-21T02:21:34.410Z  https://randomuser.me/api/portraits/women/87.jpg

# %%
df1 = pd.DataFrame(get_users())

# %% [markdown]
# We now have a pandas dataframe that can be used for any testing purposes that the tester might have.

# %% [markdown]
# ### Example 2: Fruitvice API

# %%
import requests
import json

# %%
# obtain fruitvice API using requests.get("url"). The data is in a json format. 

data = requests.get("https://fruityvice.com/api/fruit/all")

# %%
# retrieve results using json.loads() function.

results = json.loads(data.text)

# %%
# convert json data into pandas dataframe. 

pd.DataFrame(results)
# Out:
#             name  id           family             order         genus  \
# 0      Persimmon  52        Ebenaceae           Rosales     Diospyros
# 1     Strawberry   3         Rosaceae           Rosales      Fragaria
# 2         Banana   1         Musaceae      Zingiberales          Musa
# 3         Tomato   5       Solanaceae         Solanales       Solanum
# 4           Pear   4         Rosaceae           Rosales         Pyrus
# 5         Durian  60        Malvaceae          Malvales         Durio
# 6     Blackberry  64         Rosaceae           Rosales         Rubus
# 7    Lingonberry  65        Ericaceae          Ericales     Vaccinium
# 8           Kiwi  66    Actinidiaceae  Struthioniformes       Apteryx
# 9         Lychee  67      Sapindaceae        Sapindales        Litchi
# 10     Pineapple  10     Bromeliaceae            Poales        Ananas
# 11           Fig  68         Moraceae           Rosales         Ficus
# 12    Gooseberry  69  Grossulariaceae      Saxifragales         Ribes
# 13  Passionfruit  70   Passifloraceae      Malpighiales    Passiflora
# 14          Plum  71         Rosaceae           Rosales        Prunus
# 15        Orange   2         Rutaceae        Sapindales        Citrus
# 16    GreenApple  72         Rosaceae           Rosales         Malus
# 17     Raspberry  23         Rosaceae           Rosales         Rubus
# 18    Watermelon  25    Cucurbitaceae      Cucurbitales     Citrullus
# 19         Lemon  26         Rutaceae        Sapindales        Citrus
# 20         Mango  27    Anacardiaceae        Sapindales     Mangifera
# 21     Blueberry  33         Rosaceae           Rosales      Fragaria
# 22         Apple   6         Rosaceae           Rosales         Malus
# 23         Guava  37        Myrtaceae          Myrtales       Psidium
# 24       Apricot  35         Rosaceae           Rosales        Prunus
# 25        Papaya  42       Caricaceae         Caricacea        Carica
# 26         Melon  41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 27     Tangerine  77         Rutaceae        Sapindales        Citrus
# 28      Pitahaya  78        Cactaceae    Caryophyllales     Cactaceae
# 29          Lime  44         Rutaceae        Sapindales        Citrus
# 30   Pomegranate  79       Lythraceae          Myrtales        Punica
# 31   Dragonfruit  80        Cactaceae    Caryophyllales  Selenicereus
# 32         Grape  81         Vitaceae           Vitales         Vitis
# 33         Morus  82         Moraceae           Rosales         Morus
# 34        Feijoa  76        Myrtaceae        Myrtoideae    Sellowiana
# 35       Avocado  84        Lauraceae          Laurales        Persea
# 36     Kiwifruit  85    Actinidiaceae          Ericales     Actinidia
# 37     Cranberry  87        Ericaceae          Ericales     Vaccinium
# 38        Cherry   9         Rosaceae           Rosales        Prunus
# 39         Peach  86         Rosaceae           Rosales        Prunus
# 40     Jackfruit  94         Moraceae           Rosales    Artocarpus
# 41  Horned Melon  95    Cucurbitaceae      Cucurbitales       Cucumis
#
#                                            nutritions
# 0   {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1   {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2   {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3   {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4   {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...
# 5   {'calories': 147, 'fat': 5.3, 'sugar': 6.75, '...
# 6   {'calories': 40, 'fat': 0.4, 'sugar': 4.5, 'ca...
# 7   {'calories': 50, 'fat': 0.34, 'sugar': 5.74, '...
# 8   {'calories': 61, 'fat': 0.5, 'sugar': 9.0, 'ca...
# 9   {'calories': 66, 'fat': 0.44, 'sugar': 15.0, '...
# 10  {'calories': 50, 'fat': 0.12, 'sugar': 9.85, '...
# 11  {'calories': 74, 'fat': 0.3, 'sugar': 16.0, 'c...
# 12  {'calories': 44, 'fat': 0.6, 'sugar': 0.0, 'ca...
# 13  {'calories': 97, 'fat': 0.7, 'sugar': 11.2, 'c...
# 14  {'calories': 46, 'fat': 0.28, 'sugar': 9.92, '...
# 15  {'calories': 43, 'fat': 0.2, 'sugar': 8.2, 'ca...
# 16  {'calories': 21, 'fat': 0.1, 'sugar': 6.4, 'ca...
# 17  {'calories': 53, 'fat': 0.7, 'sugar': 4.4, 'ca...
# 18  {'calories': 30, 'fat': 0.2, 'sugar': 6.0, 'ca...
# 19  {'calories': 29, 'fat': 0.3, 'sugar': 2.5, 'ca...
# 20  {'calories': 60, 'fat': 0.38, 'sugar': 13.7, '...
# 21  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 22  {'calories': 52, 'fat': 0.4, 'sugar': 10.3, 'c...
# 23  {'calories': 68, 'fat': 1.0, 'sugar': 9.0, 'ca...
# 24  {'calories': 15, 'fat': 0.1, 'sugar': 3.2, 'ca...
# 25  {'calories': 43, 'fat': 0.4, 'sugar': 1.0, 'ca...
# 26  {'calories': 34, 'fat': 0.0, 'sugar': 8.0, 'ca...
# 27  {'calories': 45, 'fat': 0.4, 'sugar': 9.1, 'ca...
# 28  {'calories': 36, 'fat': 0.4, 'sugar': 3.0, 'ca...
# 29  {'calories': 25, 'fat': 0.1, 'sugar': 1.7, 'ca...
# 30  {'calories': 83, 'fat': 1.2, 'sugar': 13.7, 'c...
# 31  {'calories': 60, 'fat': 1.5, 'sugar': 8.0, 'ca...
# 32  {'calories': 69, 'fat': 0.16, 'sugar': 16.0, '...
# 33  {'calories': 43, 'fat': 0.39, 'sugar': 8.1, 'c...
# 34  {'calories': 44, 'fat': 0.4, 'sugar': 3.0, 'ca...
# 35  {'calories': 160, 'fat': 14.66, 'sugar': 0.66,...
# 36  {'calories': 61, 'fat': 0.5, 'sugar': 8.9, 'ca...
# 37  {'calories': 46, 'fat': 0.1, 'sugar': 4.0, 'ca...
# 38  {'calories': 50, 'fat': 0.3, 'sugar': 8.0, 'ca...
# 39  {'calories': 39, 'fat': 0.25, 'sugar': 8.4, 'c...
# 40  {'calories': 95, 'fat': 0.0, 'sugar': 19.1, 'c...
# 41  {'calories': 44, 'fat': 1.26, 'sugar': 0.5, 'c...

# %% [markdown]
# The result is in a nested json format. There are many nutrition subcolumns, so the data need to be normalized.

# %%
df2 = pd.json_normalize(results)
df2
# Out:
#             name  id           family             order         genus  \
# 0      Persimmon  52        Ebenaceae           Rosales     Diospyros
# 1     Strawberry   3         Rosaceae           Rosales      Fragaria
# 2         Banana   1         Musaceae      Zingiberales          Musa
# 3         Tomato   5       Solanaceae         Solanales       Solanum
# 4           Pear   4         Rosaceae           Rosales         Pyrus
# 5         Durian  60        Malvaceae          Malvales         Durio
# 6     Blackberry  64         Rosaceae           Rosales         Rubus
# 7    Lingonberry  65        Ericaceae          Ericales     Vaccinium
# 8           Kiwi  66    Actinidiaceae  Struthioniformes       Apteryx
# 9         Lychee  67      Sapindaceae        Sapindales        Litchi
# 10     Pineapple  10     Bromeliaceae            Poales        Ananas
# 11           Fig  68         Moraceae           Rosales         Ficus
# 12    Gooseberry  69  Grossulariaceae      Saxifragales         Ribes
# 13  Passionfruit  70   Passifloraceae      Malpighiales    Passiflora
# 14          Plum  71         Rosaceae           Rosales        Prunus
# 15        Orange   2         Rutaceae        Sapindales        Citrus
# 16    GreenApple  72         Rosaceae           Rosales         Malus
# 17     Raspberry  23         Rosaceae           Rosales         Rubus
# 18    Watermelon  25    Cucurbitaceae      Cucurbitales     Citrullus
# 19         Lemon  26         Rutaceae        Sapindales        Citrus
# 20         Mango  27    Anacardiaceae        Sapindales     Mangifera
# 21     Blueberry  33         Rosaceae           Rosales      Fragaria
# 22         Apple   6         Rosaceae           Rosales         Malus
# 23         Guava  37        Myrtaceae          Myrtales       Psidium
# 24       Apricot  35         Rosaceae           Rosales        Prunus
# 25        Papaya  42       Caricaceae         Caricacea        Carica
# 26         Melon  41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 27     Tangerine  77         Rutaceae        Sapindales        Citrus
# 28      Pitahaya  78        Cactaceae    Caryophyllales     Cactaceae
# 29          Lime  44         Rutaceae        Sapindales        Citrus
# 30   Pomegranate  79       Lythraceae          Myrtales        Punica
# 31   Dragonfruit  80        Cactaceae    Caryophyllales  Selenicereus
# 32         Grape  81         Vitaceae           Vitales         Vitis
# 33         Morus  82         Moraceae           Rosales         Morus
# 34        Feijoa  76        Myrtaceae        Myrtoideae    Sellowiana
# 35       Avocado  84        Lauraceae          Laurales        Persea
# 36     Kiwifruit  85    Actinidiaceae          Ericales     Actinidia
# 37     Cranberry  87        Ericaceae          Ericales     Vaccinium
# 38        Cherry   9         Rosaceae           Rosales        Prunus
# 39         Peach  86         Rosaceae           Rosales        Prunus
# 40     Jackfruit  94         Moraceae           Rosales    Artocarpus
# 41  Horned Melon  95    Cucurbitaceae      Cucurbitales       Cucumis
#
#     nutritions.calories  nutritions.fat  nutritions.sugar  \
# 0                    81            0.00             18.00
# 1                    29            0.40              5.40
# 2                    96            0.20             17.20
# 3                    74            0.20              2.60
# 4                    57            0.10             10.00
# 5                   147            5.30              6.75
# 6                    40            0.40              4.50
# 7                    50            0.34              5.74
# 8                    61            0.50              9.00
# 9                    66            0.44             15.00
# 10                   50            0.12              9.85
# 11                   74            0.30             16.00
# 12                   44            0.60              0.00
# 13                   97            0.70             11.20
# 14                   46            0.28              9.92
# 15                   43            0.20              8.20
# 16                   21            0.10              6.40
# 17                   53            0.70              4.40
# 18                   30            0.20              6.00
# 19                   29            0.30              2.50
# 20                   60            0.38             13.70
# 21                   29            0.40              5.40
# 22                   52            0.40             10.30
# 23                   68            1.00              9.00
# 24                   15            0.10              3.20
# 25                   43            0.40              1.00
# 26                   34            0.00              8.00
# 27                   45            0.40              9.10
# 28                   36            0.40              3.00
# 29                   25            0.10              1.70
# 30                   83            1.20             13.70
# 31                   60            1.50              8.00
# 32                   69            0.16             16.00
# 33                   43            0.39              8.10
# 34                   44            0.40              3.00
# 35                  160           14.66              0.66
# 36                   61            0.50              8.90
# 37                   46            0.10              4.00
# 38                   50            0.30              8.00
# 39                   39            0.25              8.40
# 40                   95            0.00             19.10
# 41                   44            1.26              0.50
#
#     nutritions.carbohydrates  nutritions.protein
# 0                      18.00                0.00
# 1                       5.50                0.80
# 2                      22.00                1.00
# 3                       3.90                0.90
# 4                      15.00                0.40
# 5                      27.10                1.50
# 6                       9.00                1.30
# 7                      11.30                0.75
# 8                      15.00                1.10
# 9                      17.00                0.80
# 10                     13.12                0.54
# 11                     19.00                0.80
# 12                     10.00                0.90
# 13                     22.40                2.20
# 14                     11.40                0.70
# 15                      8.30                1.00
# 16                      3.10                0.40
# 17                     12.00                1.20
# 18                      8.00                0.60
# 19                      9.00                1.10
# 20                     15.00                0.82
# 21                      5.50                0.00
# 22                     11.40                0.30
# 23                     14.00                2.60
# 24                      3.90                0.50
# 25                     11.00                0.00
# 26                      8.00                0.00
# 27                      8.30                0.00
# 28                      7.00                1.00
# 29                      8.40                0.30
# 30                     18.70                1.70
# 31                      9.00                9.00
# 32                     18.10                0.72
# 33                      9.80                1.44
# 34                      8.00                0.60
# 35                      8.53                2.00
# 36                     14.60                1.14
# 37                     12.20                0.40
# 38                     12.00                1.00
# 39                      9.50                0.90
# 40                     23.20                1.72
# 41                      7.56                1.78

# %%
# extract info from dataframe

kiwifruit = df2.loc[df2["name"] == 'Kiwifruit']
(kiwifruit.iloc[0]['family']) , (kiwifruit.iloc[0]['genus'])
# Out:
# ('Actinidiaceae', 'Actinidia')

# %%
# find the number of calories in avocado
